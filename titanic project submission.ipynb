# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing Dataset

# %%
df=pd.read_csv('Titanic survived Project')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df=pd.DataFrame(df)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# This dataset contains 891 rows and 12 columns

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# it is showing top 10 rows of the dataset

# %%
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# it is showing last 10 rows of the dataset

# %% [markdown]
# # Exploratory data analysis (EDA)

# %%
df.columns.to_list()
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %% [markdown]
# it is showing the list of the column present in the dataset

# %%
#checking for the type present in the dataset
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# We can clearly see here that this dataset have three types of data present
#
# 1] int64
#
#
# 2] object
#
#
# 3] float64

# %% [markdown]
# # Checking for the null values

# %%
#checking for the present of null values by graphical visualiztion b using heatmap 
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here by visualization we can clearly see that there is null value present in the dataset

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# We can clearly see here that coloumn [Age, Cabin, Embarked] has null values present so this dataset contains null value

# %%
#sum of the total null value
df.isnull().sum().sum()
# Out:
# 866

# %% [markdown]
# It is showing that this dataset has total 866 null value present

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# This gives the brief about the dataset which includes indexing type, column type, prescence of null values and memory usage.

# %% [markdown]
# # Treating null values

# %% [markdown]
# In column ["Cabin"] out of 891 values 687 values are missing which means only 204 values are present in the column so we have to drop this column because majority of the values are missing from the column

# %%
#droping the 'Cabin' column from the dataset
df=df.drop('Cabin', axis=1)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape
# Out:
# (891, 11)

# %% [markdown]
# Here we can see the column ['Cabin'] is removed from the dataset

# %% [markdown]
# Treating null values in 'Embarked' column

# %% [markdown]
# Here column["Embarked"] contains object type dataset so we use mode method to treat the null values.

# %%
print(df['Embarked'].mode())
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
print(df['Embarked'].mode()[0])
# Out:
# S

# %%
#using mode method to fill null values 
df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# dtype: int64

# %% [markdown]
# Now we treat null values in ["Age"] column. Since Age columns has numerical type data so we use mean method to treat the null values.

# %%
#using mean method to fill null values 
df['Age'].fillna(df['Age'].mean(), inplace=True)

# %%
#checking for null value
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# Here we can see that there are no null value present in the dataset

# %%
#checking for the present of null values by graphical visualiztion b using heatmap 
sns.heatmap(df.isnull(), cmap='cool_r')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here we can visualize that there is no missing value

# %%
#Checking the value counts of each column
for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# 1      1
# 599    1
# 588    1
# 589    1
# 590    1
#       ..
# 301    1
# 302    1
# 303    1
# 304    1
# 891    1
# Name: PassengerId, Length: 891, dtype: int64
#
#
# 0    549
# 1    342
# Name: Survived, dtype: int64
#
#
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64
#
#
# Braund, Mr. Owen Harris                     1
# Boulos, Mr. Hanna                           1
# Frolicher-Stehli, Mr. Maxmillian            1
# Gilinski, Mr. Eliezer                       1
# Murdlin, Mr. Joseph                         1
#                                            ..
# Kelly, Miss. Anna Katherine "Annie Kate"    1
# McCoy, Mr. Bernard                          1
# Johnson, Mr. William Cahoone Jr             1
# Keane, Miss. Nora A                         1
# Dooley, Mr. Patrick                         1
# Name: Name, Length: 891, dtype: int64
#
#
# male      577
# female    314
# Name: Sex, dtype: int64
#
#
# 29.699118    177
# 24.000000     30
# 22.000000     27
# ...

# %% [markdown]
# # Droping unnessary column

# %%
df.drop('Name', inplace=True, axis=1)

# %%
df.drop('PassengerId', inplace=True, axis=1)

# %%
df.drop('Ticket', inplace=True, axis=1)

# %%
df
# Out:
#      Survived  Pclass     Sex        Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   13.002015    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   29.699118    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# Observation=

# %% [markdown]
# 1. The summary of the dataset looks perfect since there is no negative/incvalid values present.
#
#
# 2. The counts of all the columns are same which means there are no missing values in the dataset.
#
#
# 3. In column 'PassengerId','Age','SibSp','Fare' outliers are present because there is a huge difference between 75th percentile and max value.
#
#
# 4. In column 'Survived','SibSp','Parch','Fare' mean is less than median of the data is skewed to the left.
#
#
# 5. we can also observe the standard deviation(std.), max., min., 25% percentile, 50% percentile, 75% percentile values from this describe method.

# %%
plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:].transpose(),2), linewidth=2, annot=True, fmt='f')
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# # Data visualization

# %% [markdown]
# # Univarient Analysis

# %%
sns.distplot(df['Survived'])
plt.show()

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
sns.countplot(df['Survived'])
plt.show()

# %%
sns.countplot(df['Survived'], hue='Sex', data=df)
plt.show()

# %%
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
sns.countplot(df['Sex'])
plt.show()

# %%
sns.countplot(df['Sex'], hue='Survived', data=df)
plt.show()

# %%
sns.distplot(df['Pclass'])
plt.show()

# %%
sns.countplot(df['Pclass'])
plt.show()

# %%
sns.countplot(df['Pclass'], hue='Survived', data=df)
plt.show()

# %%
sns.distplot(df['Age'])
plt.show()

# %%
sns.barplot(df['Age'])
plt.show()

# %%
sns.distplot(df['SibSp'])
plt.show()

# %%
sns.countplot(df['SibSp'])
plt.show()

# %%
sns.countplot(df['SibSp'], hue='Survived', data=df)
plt.show()

# %%
sns.distplot(df['Parch'])
plt.show()

# %%
sns.countplot(df['Parch'])
plt.show()

# %%
sns.countplot(df['Parch'], hue='Survived', data=df)
plt.show()

# %%
sns.distplot(df['Fare'])
plt.show()

# %%
sns.barplot(df['Fare'])
plt.show()

# %% [markdown]
# # Bivarient Analysis

# %%
sns.scatterplot(x='Survived', y='Age', data=df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Age'>

# %% [markdown]
# # Multivarient Analysis

# %%
sns.pairplot(df, hue='Survived')

# %%
sns.pairplot(df)

# %% [markdown]
# # Checking for the outliers

# %% [markdown]
# To detect the outliers we use boxplot visualiztion to see if outliers are present and not

# %%
plt.boxplot(df['Survived'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20943f04cd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20943f102b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20943f04b20>],
#  'medians': [<matplotlib.lines.Line2D at 0x20943f10850>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20943f10b20>],
#  'means': []}

# %%
plt.boxplot(df['Pclass'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2094515a640>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2094515abe0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2094515a340>],
#  'medians': [<matplotlib.lines.Line2D at 0x209451621c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20945162490>],
#  'means': []}

# %%
plt.boxplot(df['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2094519be50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x209451aa430>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2094519bca0>],
#  'medians': [<matplotlib.lines.Line2D at 0x209451aa9d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x209451aaca0>],
#  'means': []}

# %%
plt.boxplot(df['SibSp'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20945208820>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20945208dc0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20945208640>],
#  'medians': [<matplotlib.lines.Line2D at 0x209452163a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20945216670>],
#  'means': []}

# %%
plt.boxplot(df['Fare'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20948c1f5e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20948c1fb80>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20948c1f400>],
#  'medians': [<matplotlib.lines.Line2D at 0x20948c29160>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20948c29430>],
#  'means': []}

# %%
plt.boxplot(df['Parch'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x209452741f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20945274790>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20945267fd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x20945274d30>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20945281040>],
#  'means': []}

# %% [markdown]
# Here We can see that outliers are present in the dataset. Columns['Fare','parch','SibSp','Age'] has outliers

# %% [markdown]
# # Removing outliers

# %%
#Removing outliers
from scipy.stats import zscore
col=df[['Age','Parch','Fare']]
z=np.abs(zscore(col))

z
# Out:
#           Age     Parch      Fare
# 0    0.592481  0.473674  0.502445
# 1    0.638789  0.473674  0.786845
# 2    0.284663  0.473674  0.488854
# 3    0.407926  0.473674  0.420730
# 4    0.407926  0.473674  0.486337
# ..        ...       ...       ...
# 886  0.207709  0.473674  0.386671
# 887  0.823344  0.473674  0.044381
# 888  0.000000  2.008933  0.176263
# 889  0.284663  0.473674  0.044381
# 890  0.177063  0.473674  0.492378
#
# [891 rows x 3 columns]

# %%
#threshold value 
np.where(z>3)
# Out:
# (array([ 13,  25,  27,  86,  88,  96, 116, 118, 167, 258, 299, 311, 341,
#         360, 377, 380, 437, 438, 438, 493, 527, 557, 567, 610, 630, 638,
#         672, 678, 679, 689, 700, 716, 730, 736, 737, 742, 745, 774, 779,
#         851, 858, 885], dtype=int64),
#  array([1, 1, 2, 1, 2, 0, 0, 2, 1, 2, 2, 2, 2, 1, 2, 2, 1, 1, 2, 0, 2, 2,
#         1, 1, 0, 1, 0, 1, 2, 2, 2, 2, 2, 1, 2, 2, 0, 1, 2, 0, 1, 1],
#        dtype=int64))

# %%
#Now removing the data above zscore and creating new dF

df1=df[(z<3).all(axis=1)]

df1.shape
# Out:
# (850, 8)

# %%
df.shape
# Out:
# (891, 8)

# %%
df=df1

# %%
df.shape
# Out:
# (850, 8)

# %% [markdown]
#  Outliers are removed from the dataset

# %% [markdown]
# # Encoding Categorical Columns

# %%
#Encoding categorical columns using label Encoder

from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=LE.fit_transform(df[i].values.reshape(-1,1))
        
df
# Out:
#      Survived  Pclass  Sex        Age  SibSp  Parch     Fare  Embarked
# 0           0       3    1  22.000000      1      0   7.2500         2
# 1           1       1    0  38.000000      1      0  71.2833         0
# 2           1       3    0  26.000000      0      0   7.9250         2
# 3           1       1    0  35.000000      1      0  53.1000         2
# 4           0       3    1  35.000000      0      0   8.0500         2
# ..        ...     ...  ...        ...    ...    ...      ...       ...
# 886         0       2    1  27.000000      0      0  13.0000         2
# 887         1       1    0  19.000000      0      0  30.0000         2
# 888         0       3    0  29.699118      1      2  23.4500         2
# 889         1       1    1  26.000000      0      0  30.0000         0
# 890         0       3    1  32.000000      0      0   7.7500         1
#
# [850 rows x 8 columns]

# %% [markdown]
# Here we can see that the all the categorical columns are converted into numerical column.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 850 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  850 non-null    int64
#  1   Pclass    850 non-null    int64
#  2   Sex       850 non-null    int32
#  3   Age       850 non-null    float64
#  4   SibSp     850 non-null    int64
#  5   Parch     850 non-null    int64
#  6   Fare      850 non-null    float64
#  7   Embarked  850 non-null    int32
# dtypes: float64(2), int32(2), int64(4)
# memory usage: 53.1 KB

# %%
df.describe()
# Out:
#          Survived      Pclass         Sex         Age       SibSp       Parch  \
# count  850.000000  850.000000  850.000000  850.000000  850.000000  850.000000
# mean     0.380000    2.335294    0.657647   29.195312    0.516471    0.305882
# std      0.485672    0.821846    0.474776   12.487566    1.111175    0.622006
# min      0.000000    1.000000    0.000000    0.420000    0.000000    0.000000
# 25%      0.000000    2.000000    0.000000   22.000000    0.000000    0.000000
# 50%      0.000000    3.000000    1.000000   29.699118    0.000000    0.000000
# 75%      1.000000    3.000000    1.000000   34.000000    1.000000    0.000000
# max      1.000000    3.000000    1.000000   66.000000    8.000000    2.000000
#
#              Fare    Embarked
# count  850.000000  850.000000
# mean    26.447426    1.551765
# std     29.622706    0.779766
# min      0.000000    0.000000
# 25%      7.895800    1.000000
# 50%     13.208350    2.000000
# 75%     29.125000    2.000000
# ...

# %% [markdown]
# After encoding the categorical columns we can see all columns details here. The counts of all the columns are same that means no null values in the dataset. This describe method describe the count,mean,std.,IQR and max values of all the columns.

# %% [markdown]
# # Checking skewness

# %%
df.skew()
# Out:
# Survived    0.495326
# Pclass     -0.688801
# Sex        -0.665656
# Age         0.254775
# SibSp       3.758550
# Parch       1.855730
# Fare        2.248072
# Embarked   -1.315495
# dtype: float64

# %% [markdown]
# accpectable range is -0.5 to +0.5

# %%
df['Fare']=np.cbrt(df['Fare'])

# %%
df['Embarked']=np.cbrt(df['Embarked'])
df['Parch']=np.cbrt(df['Parch'])
df['SibSp']=np.cbrt(df['SibSp'])
df['Sex']=np.cbrt(df['Sex'])

# %%
df.skew()
# Out:
# Survived    0.495326
# Pclass     -0.688801
# Sex        -0.665656
# Age         0.254775
# SibSp       1.069777
# Parch       1.424650
# Fare        0.636830
# Embarked   -1.588691
# dtype: float64

# %%
df['Embarked']=np.cbrt(df['Embarked'])
df['Parch']=np.cbrt(df['Parch'])
df['SibSp']=np.cbrt(df['SibSp'])
df['Sex']=np.cbrt(df['Sex'])

# %%
df.skew()
# Out:
# Survived    0.495326
# Pclass     -0.688801
# Sex        -0.665656
# Age         0.254775
# SibSp       0.835450
# Parch       1.369318
# Fare        0.636830
# Embarked   -1.657650
# dtype: float64

# %%
for i in df.columns:
    sns.histplot(df[i])
    plt.show()

# %% [markdown]
# Here we can see that the skewness is removed from the dataset

# %% [markdown]
# # Correlation between target variable and independent variables

# %%
#checking the correlation
cor=df.corr()
cor
# Out:
#           Survived    Pclass       Sex       Age     SibSp     Parch  \
# Survived  1.000000 -0.331389 -0.543605 -0.060800  0.107047  0.152977
# Pclass   -0.331389  1.000000  0.134543 -0.347997 -0.067615 -0.013785
# Sex      -0.543605  0.134543  1.000000  0.082602 -0.195630 -0.231657
# Age      -0.060800 -0.347997  0.082602  1.000000 -0.174469 -0.311370
# SibSp     0.107047 -0.067615 -0.195630 -0.174469  1.000000  0.429635
# Parch     0.152977 -0.013785 -0.231657 -0.311370  0.429635  1.000000
# Fare      0.329978 -0.654921 -0.256773  0.108118  0.411204  0.328731
# Embarked -0.158570  0.203105  0.086467 -0.030538 -0.041751 -0.026013
#
#               Fare  Embarked
# Survived  0.329978 -0.158570
# Pclass   -0.654921  0.203105
# Sex      -0.256773  0.086467
# Age       0.108118 -0.030538
# SibSp     0.411204 -0.041751
# Parch     0.328731 -0.026013
# Fare      1.000000 -0.225531
# Embarked -0.225531  1.000000

# %% [markdown]
# This gives the correlation between the dependent and independent variables. we cant visualize this by plotting heatmap

# %%
plt.figure(figsize=(26,14))
sns.heatmap(df.corr(),annot=True, fmt='0.2f', linewidth=0.2, linecolor='black', cmap='Spectral')
plt.ylabel=('Features_Name')
plt.title=('Descriptive Graph')
plt.show()

# %%
cor['Survived'].sort_values(ascending=False)
# Out:
# Survived    1.000000
# Fare        0.329978
# Parch       0.152977
# SibSp       0.107047
# Age        -0.060800
# Embarked   -0.158570
# Pclass     -0.331389
# Sex        -0.543605
# Name: Survived, dtype: float64

# %% [markdown]
# We can observe the positive and negative correlated features with the target

# %% [markdown]
# # Visualizing the correlation between label and features using bar plot

# %%
plt.figure(figsize=(22,7))
df.corr()['Survived'].sort_values(ascending=False).drop(['Survived']).plot(kind='bar',color='m')
plt.show()

# %% [markdown]
# From the above bar plot we can notice the positive and negative correlation between the features and the target.

# %% [markdown]
# # Seprating features and label

# %%
df
# Out:
#      Survived  Pclass  Sex        Age  SibSp    Parch      Fare  Embarked
# 0           0       3  1.0  22.000000    1.0  0.00000  1.935438   1.08006
# 1           1       1  0.0  38.000000    1.0  0.00000  4.146318   0.00000
# 2           1       3  0.0  26.000000    0.0  0.00000  1.993730   1.08006
# 3           1       1  0.0  35.000000    1.0  0.00000  3.758647   1.08006
# 4           0       3  1.0  35.000000    0.0  0.00000  2.004158   1.08006
# ..        ...     ...  ...        ...    ...      ...       ...       ...
# 886         0       2  1.0  27.000000    0.0  0.00000  2.351335   1.08006
# 887         1       1  0.0  19.000000    0.0  0.00000  3.107233   1.08006
# 888         0       3  0.0  29.699118    1.0  1.08006  2.862294   1.08006
# 889         1       1  1.0  26.000000    0.0  0.00000  3.107233   0.00000
# 890         0       3  1.0  32.000000    0.0  0.00000  1.978946   1.00000
#
# [850 rows x 8 columns]

# %%
#seprating the independent and target variabels into x and y

x=df1.drop('Survived',axis=1)
y=df1['Survived']

print('Feature Dimension=',x.shape)
print('Label Dimension=', y.shape)
# Out:
# Feature Dimension= (850, 7)
# Label Dimension= (850,)

# %%
x
# Out:
#      Pclass  Sex        Age  SibSp    Parch      Fare  Embarked
# 0         3  1.0  22.000000    1.0  0.00000  1.935438   1.08006
# 1         1  0.0  38.000000    1.0  0.00000  4.146318   0.00000
# 2         3  0.0  26.000000    0.0  0.00000  1.993730   1.08006
# 3         1  0.0  35.000000    1.0  0.00000  3.758647   1.08006
# 4         3  1.0  35.000000    0.0  0.00000  2.004158   1.08006
# ..      ...  ...        ...    ...      ...       ...       ...
# 886       2  1.0  27.000000    0.0  0.00000  2.351335   1.08006
# 887       1  0.0  19.000000    0.0  0.00000  3.107233   1.08006
# 888       3  0.0  29.699118    1.0  1.08006  2.862294   1.08006
# 889       1  1.0  26.000000    0.0  0.00000  3.107233   0.00000
# 890       3  1.0  32.000000    0.0  0.00000  1.978946   1.00000
#
# [850 rows x 7 columns]

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 850, dtype: int64

# %% [markdown]
# # Feature Scalling Using Standard Scalarization

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x), columns=x.columns)
x
# Out:
#        Pclass       Sex       Age     SibSp     Parch      Fare  Embarked
# 0    0.809272  0.721507 -0.576537  1.406859 -0.528776 -0.797132  0.488722
# 1   -1.625706 -1.385988  0.705491  1.406859 -0.528776  1.593749 -2.131203
# 2    0.809272 -1.385988 -0.256030 -0.670986 -0.528776 -0.734094  0.488722
# 3   -1.625706 -1.385988  0.465111  1.406859 -0.528776  1.174515  0.488722
# 4    0.809272  0.721507  0.465111 -0.670986 -0.528776 -0.722817  0.488722
# ..        ...       ...       ...       ...       ...       ...       ...
# 845 -0.408217  0.721507 -0.175903 -0.670986 -0.528776 -0.347375  0.488722
# 846 -1.625706 -1.385988 -0.816918 -0.670986 -0.528776  0.470065  0.488722
# 847  0.809272 -1.385988  0.040368  1.406859  2.000571  0.205185  0.488722
# 848 -1.625706  0.721507 -0.256030 -0.670986 -0.528776  0.470065 -2.131203
# 849  0.809272  0.721507  0.224731 -0.670986 -0.528776 -0.750082  0.294519
#
# [850 rows x 7 columns]

# %% [markdown]
# We have scaled the data using standard scalarization method to overcome the issue of biasness standard scaler will convert mean=0 and std=1
#
# Now we check for the multicolinearity for this we use Variance Inflation factor(VIF) method

# %% [markdown]
# # Oversampling method for balancing of the data set

# %%
#Checking value count of target column
y.value_counts()
# Out:
# 0    527
# 1    323
# Name: Survived, dtype: int64

# %%
#oversampling the data
from imblearn.over_sampling import SMOTE
sm=SMOTE()
x,y=sm.fit_resample(x,y)

# %%
#Checking value count of target column
y.value_counts()
# Out:
# 0    527
# 1    527
# Name: Survived, dtype: int64

# %% [markdown]
# Here we can see that both 0 & 1 has equal number of values we use this to prevent the biaseness in the dataset

# %% [markdown]
# # Checking Variance Inflation factor(VIF)

# %%
#Finding varience inflation factor in each scaled column

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['VIF Values']=[variance_inflation_factor(x.values,i)
            for i in range(len(x.columns))]
vif['Features']=x.columns
vif
# Out:
#    VIF Values  Features
# 0    2.413963    Pclass
# 1    1.115717       Sex
# 2    1.321411       Age
# 3    1.417454     SibSp
# 4    1.433447     Parch
# 5    2.883658      Fare
# 6    1.091243  Embarked

# %% [markdown]
# Here we can say that there is no multicolinearity present in the dataset so no need to remove the multicolinearity

# %% [markdown]
# # Modeling

# %% [markdown]
# Since the outcome has only two variable we will use binary clasification model

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, accuracy_score

# %% [markdown]
# Splitting the dataframe:

# %% [markdown]
# # Finding best random state

# %%
for i in range(0,1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i, test_size=0.20)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    if round(accuracy_score(y_train, pred_train)*100,1)==round(accuracy_score(y_test,pred_test)*100,1):
        print('At random state',i, 'The model performs very well')
        print('At random state:-',i)
        print("Training accuracy is:-", accuracy_score(y_train,pred_train)*100)
        print("Testing accuracy is:-", accuracy_score(y_test,pred_test)*100)
# Out:
# At random state 54 The model performs very well
# At random state:- 54
# Training accuracy is:- 80.0711743772242
# Testing accuracy is:- 80.09478672985783
# At random state 96 The model performs very well
# At random state:- 96
# Training accuracy is:- 79.12218268090155
# Testing accuracy is:- 79.14691943127961
# At random state 120 The model performs very well
# At random state:- 120
# Training accuracy is:- 80.0711743772242
# Testing accuracy is:- 80.09478672985783
# At random state 125 The model performs very well
# At random state:- 125
# Training accuracy is:- 79.59667852906287
# Testing accuracy is:- 79.62085308056872
# At random state 222 The model performs very well
# At random state:- 222
# Training accuracy is:- 79.12218268090155
# Testing accuracy is:- 79.14691943127961
# At random state 240 The model performs very well
# At random state:- 240
# Training accuracy is:- 79.12218268090155
# Testing accuracy is:- 79.14691943127961
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=54)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.55      0.54      0.54       106
#            1       0.54      0.55      0.55       105
#
#     accuracy                           0.55       211
#    macro avg       0.55      0.55      0.55       211
# weighted avg       0.55      0.55      0.55       211

# %% [markdown]
# # cross validation score for logistic regression

# %%
pred_lr=lr.predict(x_test)

from sklearn.model_selection import cross_val_score
lss=accuracy_score(y_test,pred_lr)
for j in range(2,10):
    lsscore=cross_val_score(lr,x,y,cv=j)
    lsc=lsscore.mean()
    print('At cv:-', j)
    print('Cross validation score is:-', lsc*100)
    print('accuracy_score is :-',
          lss*100)
    print('\n')
# Out:
# At cv:- 2
# Cross validation score is:- 79.60151802656547
# accuracy_score is :- 79.62085308056872
#
#
# At cv:- 3
# Cross validation score is:- 79.03311965811966
# accuracy_score is :- 79.62085308056872
#
#
# At cv:- 4
# Cross validation score is:- 78.656815301302
# accuracy_score is :- 79.62085308056872
#
#
# At cv:- 5
# Cross validation score is:- 79.0340780862108
# accuracy_score is :- 79.62085308056872
#
#
# At cv:- 6
# Cross validation score is:- 78.94372294372295
# accuracy_score is :- 79.62085308056872
#
#
# At cv:- 7
# Cross validation score is:- 78.65909807631661
# accuracy_score is :- 79.62085308056872
#
#
# At cv:- 8
# Cross validation score is:- 78.85004626416841
# accuracy_score is :- 79.62085308056872
#
#
# At cv:- 9
# Cross validation score is:- 78.8441418384921
# accuracy_score is :- 79.62085308056872

# %%
lsscore_selected=cross_val_score(lr,x,y,cv=5).mean()
print('The cv Score is:', lsscore_selected, '\n The accuracy score is:', lss)
# Out:
# The cv Score is: 0.7903407808621079
#  The accuracy score is: 0.7962085308056872

# %%
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier, BaggingClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
RFC=RandomForestClassifier()
RFC.fit(x_train, y_train)
predRFC=RFC.predict(x_test)
print(accuracy_score(y_test, predRFC))
print(confusion_matrix(y_test, predRFC))
print(classification_report(y_test,predRFC))
# Out:
# 0.8530805687203792
# [[91 15]
#  [16 89]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.86      0.85       106
#            1       0.86      0.85      0.85       105
#
#     accuracy                           0.85       211
#    macro avg       0.85      0.85      0.85       211
# weighted avg       0.85      0.85      0.85       211

# %%
score=cross_val_score(RFC,x,y,cv=4)
print(score)
print(score.mean())
print('Difference between accuracy score and cross validation score is ', accuracy_score(y_test,predRFC)-score.mean())
# Out:
# [0.77272727 0.82954545 0.85551331 0.85551331]
# 0.8283248358105773
# Difference between accuracy score and cross validation score is  0.02475573290980193

# %%
from sklearn.svm import SVC
svc=SVC()
svc.fit(x_train,y_train)
predsvc=svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test, predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 0.8341232227488151
# [[88 18]
#  [17 88]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.83      0.83       106
#            1       0.83      0.84      0.83       105
#
#     accuracy                           0.83       211
#    macro avg       0.83      0.83      0.83       211
# weighted avg       0.83      0.83      0.83       211

# %%
#checking cv score for support vector machine classifier
score=cross_val_score(svc,x,y)
print(score)
print(score.mean())
print('Difference between Accuracy score and cross validation score is:-', accuracy_score(y_test,predsvc)- score.mean())
# Out:
# [0.77251185 0.8056872  0.77725118 0.82938389 0.86190476]
# 0.8093477770255021
# Difference between Accuracy score and cross validation score is:- 0.024775445723313028

# %%
#checking accuracy for gradient boosting classifier
GB=GradientBoostingClassifier()
GB.fit(x_train,y_train)
predGB=GB.predict(x_test)
print(accuracy_score(y_test,predGB))
print(confusion_matrix(y_test,predGB))
print(classification_report(y_test,predGB))
# Out:
# 0.8530805687203792
# [[91 15]
#  [16 89]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.86      0.85       106
#            1       0.86      0.85      0.85       105
#
#     accuracy                           0.85       211
#    macro avg       0.85      0.85      0.85       211
# weighted avg       0.85      0.85      0.85       211

# %%
#checking cv score for gradient boosting classifier
score=cross_val_score(GB,x,y,scoring='accuracy')
print(score)
print(score.mean())
print("Diference betwen f1 score and cross validation score is ", (y_test,predGB)-score.mean())
# Out:
# [0.79146919 0.81516588 0.81990521 0.88625592 0.85238095]
# 0.8330354321823517
# Diference betwen f1 score and cross validation score is  [[ 0.16696457  0.16696457  0.16696457 -0.83303543 -0.83303543 -0.83303543
#    0.16696457 -0.83303543 -0.83303543 -0.83303543  0.16696457 -0.83303543
#   -0.83303543  0.16696457  0.16696457  0.16696457  0.16696457 -0.83303543
#   -0.83303543  0.16696457  0.16696457  0.16696457  0.16696457  0.16696457
#    0.16696457 -0.83303543  0.16696457 -0.83303543  0.16696457  0.16696457
#    0.16696457 -0.83303543 -0.83303543 -0.83303543  0.16696457 -0.83303543
#    0.16696457  0.16696457  0.16696457  0.16696457 -0.83303543  0.16696457
#    0.16696457 -0.83303543 -0.83303543  0.16696457  0.16696457 -0.83303543
#   -0.83303543 -0.83303543  0.16696457 -0.83303543  0.16696457 -0.83303543
#    0.16696457 -0.83303543 -0.83303543  0.16696457  0.16696457 -0.83303543
#   -0.83303543  0.16696457 -0.83303543  0.16696457  0.16696457  0.16696457
# ...

# %%
#checking accuracy for ExtraTrees classifier
ET=ExtraTreesClassifier()
ET.fit(x_train,y_train)
predET=ET.predict(x_test)
print(accuracy_score(y_test,predET))
print(confusion_matrix(y_test,predET))
print(classification_report(y_test,predET))
# Out:
# 0.8388625592417062
# [[88 18]
#  [16 89]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.83      0.84       106
#            1       0.83      0.85      0.84       105
#
#     accuracy                           0.84       211
#    macro avg       0.84      0.84      0.84       211
# weighted avg       0.84      0.84      0.84       211

# %%
#checking cv score for extra trees classifier
score=cross_val_score(ET,x,y)
print(score)
print(score.mean())
print("Diference between Accuracy score and cross validation score is ", accuracy_score(y_test,predET)-score.mean())
# Out:
# [0.76303318 0.80094787 0.80094787 0.86729858 0.82857143]
# 0.8121597833446174
# Diference between Accuracy score and cross validation score is  0.026702775897088804

# %% [markdown]
# # Hyper parameter tuning

# %%
#Random Forest Classifier
from sklearn.model_selection import GridSearchCV

parameters= {'criterion' : ['gini', 'entropy'],
             'random_state' : [10,50,1000],
             'max_depth' : [0,10,20],
            'n_jobs' : [-2,-1,1],
             'n_estimators': [50,100,200,300]}

# %%
GVC=GridSearchCV(RandomForestClassifier(), parameters, cv=5)

# %%
GVC.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [0, 10, 20],
#                          'n_estimators': [50, 100, 200, 300],
#                          'n_jobs': [-2, -1, 1],
#                          'random_state': [10, 50, 1000]})

# %%
GVC.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 10,
#  'n_estimators': 100,
#  'n_jobs': -2,
#  'random_state': 10}

# %%
Final_model=RandomForestClassifier(criterion='entropy', max_depth=10, n_estimators=100, n_jobs=-2, random_state=10)
Final_model.fit(x_train,y_train)
pred=Final_model.predict(x_test)
acc=accuracy_score(y_test,pred)
print(acc*100)
# Out:
# 84.36018957345972

# %% [markdown]
# # AUC ROC Curve

# %%
from sklearn.metrics import roc_curve, auc
fpr, tpr, thresholds= roc_curve(pred_test, y_test)
roc_auc=auc(fpr,tpr)

plt.figure()
plt.plot(fpr,tpr,color='darkorange', lw=10, label= 'ROC curve (area=%0.2f)' %roc_auc)
plt.plot([0,1], [0,1], color='navy', lw=10, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.legend(loc='lower right')
plt.show()

# %%
from sklearn.metrics import plot_roc_curve
disp=plot_roc_curve(ET, x_test,y_test)  #ax=Axes with confusion matrix
plot_roc_curve(RFC, x_test, y_test, ax=disp.ax_)

plot_roc_curve(svc, x_test, y_test, ax=disp.ax_)
plot_roc_curve(GB, x_test, y_test, ax=disp.ax_)

plt.legend(prop={'size':11}, loc= 'lower right')

plt.show()

# %% [markdown]
# # Model saving

# %%
#saving the model
import joblib
joblib.dump(Final_model, "Titanic dataset Model.pkl")
# Out:
# ['Titanic dataset Model.pkl']

# %% [markdown]
# # Conclusion

# %%
import numpy as np
a=np.array(y_test)
predict=np.array(lr.predict(x_test))
df_com=pd.DataFrame({'Original':a, 'Predicted':predict}, index=range(len(a)))
df_com
# Out:
#      Original  Predicted
# 0           1          1
# 1           1          0
# 2           1          0
# 3           0          0
# 4           0          0
# ..        ...        ...
# 206         0          0
# 207         0          0
# 208         1          1
# 209         1          1
# 210         1          1
#
# [211 rows x 2 columns]

# %% [markdown]
# Predicting survived or not by providing random input

# %%
#Load the model
model=joblib.load('Titanic dataset Model.pkl')


#prediction
input_data=(3,1.0,22.000000,1.0,0.000000,1.935438,1.08006)


#change the input data into numpy array
array=np.asarray(input_data)


#reshape the data as we are predicting the label for only one instance
array_reshape=array.reshape(1,-1)

prediction=model.predict(array_reshape)


print(prediction)


if (prediction[0]==0):
    print('Not Survived')
    
else:
    print('Survived')
# Out:
# [0]
# Not Survived
